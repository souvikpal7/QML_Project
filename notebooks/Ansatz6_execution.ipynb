# %%
import sys
sys.path.append(r"C:\Users\conta\D\MTech\sem5\QML\project\qml_proj")

# %%
data_dir = r"C:\Users\conta\D\MTech\sem5\QML\project\notebooks\rice_UCI"

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from qiskit_algorithms.optimizers import COBYLA
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier
from TranspiledCircuit.TranspiledQNN import TranspiledQNN
from CustomQNN.Custom import CustomEstimatorQNN
import warnings
warnings.filterwarnings('ignore')

# %%
# api_token = r"your_api_key_here"
# service = QiskitRuntimeService(
#     channel= "ibm_quantum",
#     token= api_token
# )

# QiskitRuntimeService.save_account(channel= "ibm_quantum", token=api_token)

# %%
service = QiskitRuntimeService(channel="ibm_quantum")

# %%
backend = service.backend(name='ibmq_qasm_simulator')

# %%
X_scaled_path = os.path.join(data_dir, "rice_scaled.npy")
y_path = os.path.join(data_dir, "labels.npy")

# %%
def load_np_data(np_obj_path):
    assert os.path.exists(np_obj_path), "Path does not exists"
    with open(np_obj_path, "rb") as file:
        var = np.load(file, allow_pickle=True)
    return var

# %%
X_enc = load_np_data(X_scaled_path)
print(f"X_enc shape: {X_enc.shape}")

print()
Y = load_np_data(y_path)
print(f"Y shape: {Y.shape}")
# Out:
# X_enc shape: (3810, 7)
#
# Y shape: (3810,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_enc, Y, random_state=711)
X_train = X_train[:50]
Y_train = Y_train[:50]

X_test = X_test[:50]
Y_test = Y_test[:50]

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (50, 7)
# (50,)
# (50, 7)
# (50,)

# %%
Y_train = np.where(Y_train==0, -1, 1)
Y_test = np.where(Y_test==0, -1, 1)

# %% [markdown]
# ## Classification Using Custom EstimatorQNN

# %% [markdown]
# ### Section 1 <br> In Below Section Ansatz is used with **Angle Encoding** and Repetation value of **2**

# %%
ANSATZ_NAME = "ansatz6"
ENCODING = ["angle", "angle", "zz"]
DEPTH = [2, 5, 5]

# %%
ip_dim = X_train.shape[1]
trans_crc = TranspiledQNN(ip_dim, ENCODING[0], ANSATZ_NAME, DEPTH[0], backend)
trans_crc_qc = trans_crc.get_circuit()
trans_layout = trans_crc.get_circuit_layout()

# %%
trans_crc_qc.draw("mpl", style="clifford")

# %%
cnt_wei_params = len(trans_crc_qc.weight_parameters)
estimator_qnn = CustomEstimatorQNN(trans_crc_qc, service, backend)

# %%
objective_func_vals = []

def saving_obj_vals(weights, obj_func_eval):
    objective_func_vals.append(obj_func_eval)

# %%
# construct neural network classifier
estimator_classifier = NeuralNetworkClassifier(
    estimator_qnn, 
    optimizer=COBYLA(maxiter=cnt_wei_params * 3), 
    callback=saving_obj_vals
)

# %%
# fit classifier to data
estimator_classifier.fit(X_train[:15], Y_train[:15])

# score classifier
test_score1 = estimator_classifier.score(X_test, Y_test)
print(f"Test score: {test_score1}")
# Out:
# ---------------------------------------------------------------------------
# IBMRuntimeError                           Traceback (most recent call last)
# Cell In[20], line 2
#       1 # fit classifier to data
# ----> 2 estimator_classifier.fit(X_train[:15], Y_train[:15])
#       4 # score classifier
#       5 test_score1 = estimator_classifier.score(X_test, Y_test)
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:199, in TrainableModel.fit(self, X, y)
#     196 if not self._warm_start:
#     197     self._fit_result = None
# --> 199 self._fit_result = self._fit_internal(X, y)
#     200 return self
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_machine_learning\algorithms\classifiers\neural_network_classifier.py:115, in NeuralNetworkClassifier._fit_internal(self, X, y)
#     112 X, y = self._validate_input(X, y)
#     114 function = self._create_objective(X, y)
# --> 115 return self._minimize(function)
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:295, in TrainableModel._minimize(self, function)
#     291     optimizer_result = self._optimizer(
#     292         fun=objective, x0=initial_point, jac=function.gradient
#     293     )
#     294 else:
# --> 295     optimizer_result = self._optimizer.minimize(
#     296         fun=objective,
#     297         x0=initial_point,
#     298         jac=function.gradient,
#     299     )
#     300 return optimizer_result
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_algorithms\optimizers\scipy_optimizer.py:148, in SciPyOptimizer.minimize(self, fun, x0, jac, bounds)
#     145     swapped_deprecated_args = True
#     146     self._options["maxfun"] = self._options.pop("maxiter")
# --> 148 raw_result = minimize(
#     149     fun=fun,
#     150     x0=x0,
#     151     method=self._method,
#     152     jac=jac,
#     153     bounds=bounds,
#     154     options=self._options,
#     155     **self._kwargs,
#     156 )
#     157 if swapped_deprecated_args:
#     158     self._options["maxiter"] = self._options.pop("maxfun")
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
# --> 719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:271, in TrainableModel._get_objective.<locals>.objective(objective_weights)
#     270 def objective(objective_weights):
# --> 271     objective_value = function.objective(objective_weights)
#     272     self._callback(objective_weights, objective_value)
#     273     return objective_value
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_machine_learning\algorithms\objective_functions.py:115, in BinaryObjectiveFunction.objective(self, weights)
#     113 def objective(self, weights: np.ndarray) -> float:
#     114     # predict is of shape (N, 1), where N is a number of samples
# --> 115     predict = self._neural_network_forward(weights)
#     116     target = np.array(self._y).reshape(predict.shape)
#     117     # float(...) is for mypy compliance
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_machine_learning\algorithms\objective_functions.py:102, in ObjectiveFunction._neural_network_forward(self, weights)
#      97 # if we get the same weights, we don't compute the forward pass again.
#      98 if self._last_forward_weights is None or (
#      99     not np.all(np.isclose(weights, self._last_forward_weights))
#     100 ):
#     101     # compute forward and cache the results for re-use in backward
# --> 102     self._last_forward = self._neural_network.forward(self._X, weights)
#     103     # a copy avoids keeping a reference to the same array, so we are sure we have
#     104     # different arrays on the next iteration.
#     105     self._last_forward_weights = np.copy(weights)
#
# File ~\D\MTech\sem5\QML\project\qml_proj\CustomQNN\Custom.py:83, in CustomEstimatorQNN.forward(self, input_data, weights)
#      81 input_data = np.array(input_data)
#      82 input_, shape = input_data, input_data.shape
# ---> 83 output_data = self._forward(input_, weights)
#      84 return self._validate_forward_output(output_data, shape)
#
# File ~\D\MTech\sem5\QML\project\qml_proj\CustomQNN\Custom.py:98, in CustomEstimatorQNN._forward(self, input_data, weights)
#      92 with Session(service=self.service, backend=self.backend) as session:
#      93     estimator = Estimator(
#      94         backend=self.backend,
#      95         options=self._estimator_options
#      96         )
# ---> 98     job = estimator.run(
#      99         [self._circuit] * num_samples * self.output_shape[0],
#     100         [op for op in self._observables for _ in range(num_samples)],
#     101         np.tile(parameter_values_, (self.output_shape[0], 1)),
#     102     )
#     103     try:
#     104         results = job.result()
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_ibm_runtime\estimator.py:290, in EstimatorV1.run(self, circuits, observables, parameter_values, **kwargs)
#     288 # To bypass base class merging of options.
#     289 user_kwargs = {"_user_kwargs": kwargs}
# --> 290 return super().run(
#     291     circuits=circuits,
#     292     observables=observables,
#     293     parameter_values=parameter_values,
#     294     **user_kwargs,
#     295 )
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit\primitives\base\base_estimator.py:175, in BaseEstimatorV1.run(self, circuits, observables, parameter_values, **run_options)
#     172 run_opts = copy(self.options)
#     173 run_opts.update_options(**run_options)
# --> 175 return self._run(
#     176     circuits,
#     177     observables,
#     178     parameter_values,
#     179     **run_opts.__dict__,
#     180 )
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_ibm_runtime\estimator.py:326, in EstimatorV1._run(self, circuits, observables, parameter_values, **kwargs)
#     304 """Submit a request to the estimator primitive.
#     305
#     306 Args:
#    (...)
#     318     Submitted job
#     319 """
#     320 inputs = {
#     321     "circuits": circuits,
#     322     "observables": observables,
#     323     "parameters": [circ.parameters for circ in circuits],
#     324     "parameter_values": parameter_values,
#     325 }
# --> 326 return self._run_primitive(
#     327     primitive_inputs=inputs, user_kwargs=kwargs.get("_user_kwargs", {})
#     328 )
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_ibm_runtime\base_primitive.py:407, in BasePrimitiveV1._run_primitive(self, primitive_inputs, user_kwargs)
#     404         runtime_options["instance"] = self._backend._instance
#     406 if isinstance(self._service, QiskitRuntimeService):
# --> 407     return self._service.run(
#     408         program_id=self._program_id(),  # type: ignore[arg-type]
#     409         options=runtime_options,
#     410         inputs=primitive_inputs,
#     411         callback=combined.get("environment", {}).get("callback", None),
#     412         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     413     )
#     414 return self._service.run(  # type: ignore[call-arg]
#     415     program_id=self._program_id(),  # type: ignore[arg-type]
#     416     options=runtime_options,
#     417     inputs=primitive_inputs,
#     418 )
#
# File c:\Users\conta\miniconda3\envs\qml1\lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:884, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#     882     if ex.status_code == 404:
#     883         raise RuntimeProgramNotFound(f"Program not found: {ex.message}") from None
# --> 884     raise IBMRuntimeError(f"Failed to run program: {ex}") from None
#     885 backend = (
#     886     self.backend(name=response["backend"], instance=hgp_name)
#     887     if response["backend"]
#     888     else qrt_options.get_backend_name()
#     889 )
#     891 if version == 2:
#
# IBMRuntimeError: 'Failed to run program: "(\'Connection aborted.\', RemoteDisconnected(\'Remote end closed connection without response\'))"'

# %%
plt.plot(range(1, len(objective_func_vals) + 1), objective_func_vals)
plt.title("Objective function value against iteration")
plt.xlabel("Iteration")
plt.ylabel("Objective function value")
plt.show()

# %% [markdown]
# ### Section 2 <br> In Below Section Ansatz is used with **Angle Encoding** and Repetation value of **5**

# %%
ip_dim = X_train.shape[1]
trans_crc = TranspiledQNN(ip_dim, ENCODING[1], ANSATZ_NAME, DEPTH[1], backend)
trans_crc_qc = trans_crc.get_circuit()
trans_layout = trans_crc.get_circuit_layout()

# %%
trans_crc_qc.draw("mpl", style="clifford")

# %%
objective_func_vals = []
cnt_wei_params = len(trans_crc_qc.weight_parameters)
estimator_qnn = CustomEstimatorQNN(trans_crc_qc, service, backend)

# construct neural network classifier
estimator_classifier = NeuralNetworkClassifier(
    estimator_qnn, 
    optimizer=COBYLA(maxiter=cnt_wei_params * 3), 
    callback=saving_obj_vals
)

# %%
# fit classifier to data
estimator_classifier.fit(X_train[:15], Y_train[:15])

# score classifier
test_score2 = estimator_classifier.score(X_test, Y_test)
print(f"Test score: {test_score2}")

# %%
plt.plot(range(1, len(objective_func_vals) + 1), objective_func_vals)
plt.title("Objective function value against iteration")
plt.xlabel("Iteration")
plt.ylabel("Objective function value")
plt.show()

# %% [markdown]
# ### Section 3 <br> In Below Section Ansatz is used with **ZZ Encoding** and Repetation value of **5**

# %%
ip_dim = X_train.shape[1]
trans_crc = TranspiledQNN(ip_dim, ENCODING[2], ANSATZ_NAME, DEPTH[2], backend)
trans_crc_qc = trans_crc.get_circuit()
trans_layout = trans_crc.get_circuit_layout()

# %%
trans_crc_qc.draw("mpl", style="clifford")

# %%
objective_func_vals = []
cnt_wei_params = len(trans_crc_qc.weight_parameters)
estimator_qnn = CustomEstimatorQNN(trans_crc_qc, service, backend)

# construct neural network classifier
estimator_classifier = NeuralNetworkClassifier(
    estimator_qnn, 
    optimizer=COBYLA(maxiter=cnt_wei_params * 3), 
    callback=saving_obj_vals
)

# %%
# fit classifier to data
estimator_classifier.fit(X_train[:15], Y_train[:15])

# score classifier
test_score3 = estimator_classifier.score(X_test, Y_test)
print(f"Test score: {test_score3}")

# %%
plt.plot(range(1, len(objective_func_vals) + 1), objective_func_vals)
plt.title("Objective function value against iteration")
plt.xlabel("Iteration")
plt.ylabel("Objective function value")
plt.show()

# %% [markdown]
# ## Writing Rresults in .csv File

# %%
import pandas as pd

ansatz_name = ANSATZ_NAME
result_path = r"C:\Users\conta\D\MTech\sem5\QML\project\qml_proj\results.csv"

data = {
    'Ansatz Name': [ansatz_name]*3, 
    'Encoding': ENCODING, 
    'Depth': DEPTH, 
    'test_score': [test_score1, test_score2, test_score3]
    }

df = pd.DataFrame(data)

if os.path.exists(result_path):
    df_existing = pd.read_csv(result_path)
else:
    df_existing = pd.DataFrame()


df_res = pd.concat([df_existing, df], ignore_index=True)
df_res.to_csv(result_path, index=False)
